# %% [markdown]
# <a href="https://colab.research.google.com/github/zaebee/assets/blob/master/Tales%20AI%20Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cohere
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for cohere: filename=cohere-2.9.1-cp38-cp38-linux_x86_64.whl size=9627 sha256=1b48c9047ece5abd7b25e92fe08cba17b4d9f9dc8ea7bf7c7c137cf0248c9425
#   Stored in directory: /root/.cache/pip/wheels/c8/79/5b/36adcce533f4b0ed540beef7e6ea61d637a10cb2c8d4670153
# Successfully built cohere
# ...

# %%
TALES = [{
    'name': 'mary',
    'heroes': '',
    'summary': (
        'A fairy tale about a daughter who was cared for by the virgin. '
        'The girl deceived her, and the Mother of God punished her for it.'),
    'struct': '''
1) Absence (the Virgin Mary has a long way to go. So, she gives the girls the keys to the thirteen gates of heaven)
2) Prohibition (You can do twelve doors, but I forbid you to open the thirteenth door! Do not open it, otherwise you will be unhappy!)
3) Violation (Once, when all the angels left, out of curiosity, the girl nevertheless opened the thirteenth door)
4) Finding out (On her return, the Ever-Virgin looked into her eyes and asked: “Have you unlocked the thirteenth door too?” “No”)
5) Issuance (Virgin Mary demanded the keys back)
6) A catch (the Virgin Mary found out about the deception and said: “You disobeyed me and, in addition, you lied, and therefore you are not worthy to stay in heaven anymore!”)
7) Aiding (The King continued: “Would you like to come with me to my castle?” To this she answered only with a slight nod of her head)
8) Wrecking (the Blessed Virgin took three children, wanting to hear the truth and repentance)
9) Mediation (I am the Virgin Mary, the mother of the infant Christ. You are poor, burdened with need. Bring me your child: I will take him with me, I will be his mother and take care of him)
10) Sending (The woodcutter obeyed, brought his child and handed him to the Virgin Mary, who took him to heaven with her)
11) Victory (The Queen repented that she opened the door. Then the voice returned to her, and she loudly confessed to Mary what she had done. And at the same moment it rained from heaven and extinguished the flame. The Virgin Mary descended to earth with her newborn daughter)''',
    'text': '''
A poor woodcutter and his wife had a three-year-old daughter that they could not feed. 
The Virgin Mary appeared to the woodcutter and promised to take care of the child, so they gave her the child.
She grew up happily in Heaven. One day the Virgin had to go on a journey and gave the girl keys, 
telling her she could open twelve doors but not the thirteenth. She opened the first twelve and found 
the Apostles behind them. Then she opened the thirteenth door. Behind it was the Trinity, and her finger 
was stained with gold. She tried to hide it, lying three times, and the Virgin Mary said she could no longer remain for her disobedience and lying.

She fell asleep and woke to find herself in a forest. Lamenting her misfortune, she lived in a hollow tree, 
ate wild plants, and tore all her clothing until she was naked. One day, a king found her looking beautiful 
but incapable of speech. He took her home and married her.

A year later, she had a son. The Virgin Mary appeared and demanded that she confess to having opened the door. 
She lied again, the Virgin took her son, and the people whispered that she had killed and eaten the child. 
In another year, she had another son, and it went as before. The third year, she had a daughter, and the Virgin Mary 
took her to heaven and showed her her sons, but she would not confess. This time, the king could not restrain 
his councilors, and the queen was condemned to death. When she was brought to the stake, she relented and wished 
she could confess before she died. The Virgin Mary brought back her children, restored her the power of speech, 
and gave her happiness the rest of her life.'''
}, {
    'name': 'bun',
    'heroes': '''<character> Luke Skywalker <description> Luke Skywalker is the hero. A naive farm boy, he will discover
special powers under the guidance of mentor Ben Kenobi. <stop>
<character> Ben Kenobi <description> Ben Kenobi is the mentor figure. A recluse Jedi warrior, he will
take Luke Skywalker as apprentice. <stop>
<character> Darth Vader <description> Darth Vader is the antagonist. As a commander of the evil Galactic
and an apple, and a pie. As she left, she thanked everyone for their help. 
And from the oven - immediately home. Soon the parents returned.''',
}]

# %%
#@title Import Cohere, set up some things { display-mode: "form" }

import cohere
import time
import pandas as pd
import re
import io
import os
import warnings
from IPython.display import display
from PIL import Image

COHERE_KEY = 'onk1aMdIZZ4P86E99JlD095UEVH7LfIUwwmEF7KQ'
STABILITY_KEY = 'sk-kKDdwGtHoPO4kiOSWQck3D1TEaBRRAVMUPhdKyHUN9A0DVH3'

# Paste your API key here. Remember to not share it publicly 
os.environ['COHERE_KEY'] = COHERE_KEY 
co = cohere.Client(os.environ['COHERE_KEY'])

# To get your API key, visit https://beta.dreamstudio.ai/membership
os.environ['STABILITY_KEY'] = STABILITY_KEY

def generate(prompt, model='xlarge', num_generations=5, temperature=0.7, max_tokens=50, stop_sequences=['<end>']):
  prediction = co.generate(
    model=model,
    prompt=prompt,
    return_likelihoods = 'GENERATION',
    stop_sequences=stop_sequences,
    max_tokens=max_tokens,
    temperature=temperature,
    num_generations=num_generations)
  
  # Get list of generations
  gens = []
  likelihoods = []
  for gen in prediction.generations:
      gens.append(gen.text)
      
      sum_likelihood = 0
      for t in gen.token_likelihoods:
          sum_likelihood += t.likelihood
      # Get sum of likelihoods
      likelihoods.append(sum_likelihood)

  pd.options.display.max_colwidth = 200
  # Create a dataframe for the generated sentences and their likelihood scores
  df = pd.DataFrame({'generation':gens, 'likelihood': likelihoods})
  # Drop duplicates
  df = df.drop_duplicates(subset=['generation'])
  # Sort by highest sum likelihood
  df = df.sort_values('likelihood', ascending=False, ignore_index=True)
  
  return df

# %%
class TalePrompt:
  """Generates prompts for tale structure and text."""

  HEAD = ('Examples of breakdowns of story into Vladimir Propp\'s '
          '"Morphology of a fairy tale" structutre.\n')
  
  SAMPLE = 'Example {counter}.\n{text}\n\n<scenes>\n{predict}\n\n<end>\n'
  SAMPLE_PREDICT = 'Example {counter}. \n{text}\n\n<scenes>'
  
  HEROES = 'Example {counter}.\n{text}\nCharacters and descriptions:\n{heroes}\n<end>'
  HEROES_PREDICT = 'Example {counter}.\n{text}\nCharacters and descriptions:'  

  def __init__(self, line, as_tale=None, *args, **kwargs):
    self.heroes = {}
    self.structures = {}
    self.line = line
    self.as_tale = as_tale
    self.tales = kwargs.get('tales', TALES)

  def prompt_structure(self, text) -> str:
    """Generates prompt to get tale structure."""
    output = [self.HEAD]
    for counter, tale in enumerate(self.tales, 1):
      sample = self.SAMPLE.format(
          counter=counter, text=tale['summary'], predict=tale['struct'])
      output.append(sample)
    predict = self.SAMPLE_PREDICT.format(
        counter=len(self.tales) + 1, text=text)
    output.append(predict)
    return '\n'.join(output)

  def prompt_text_as_tale(self, text, as_tale) -> str:
    """Generates prompt to get tale full text."""
    tales = [tale for tale in self.tales if tale['name'] == as_tale]
    output = [self.HEAD]
    if not tales:
      return ''
    for counter, tale in enumerate(tales, 1):
      summary = '\n'.join([tale['summary'], tale['struct']])
      sample = self.SAMPLE.format(
          counter=counter, text=summary, predict=tale['text'])
      output.append(sample)
    predict = self.SAMPLE_PREDICT.format(counter=len(tales) + 1, text=text)
    output.append(predict)
    return '\n'.join(output)

  def prompt_structure_as_tale(self, text, as_tale) -> str:
    """Generates prompt to predict tale structure similar as given tale."""
    tales = [tale for tale in self.tales if tale['name'] == as_tale]
    output = [self.HEAD]
    if not tales:
      return ''
    for counter, tale in enumerate(tales, 1):
      sample = self.SAMPLE.format(
          counter=counter, text=tale['text'], predict=tale['struct'])
      output.append(sample)
    predict = self.SAMPLE_PREDICT.format(counter=len(tales) + 1, text=text)
    output.append(predict)
    return '\n'.join(output)

  def prompt_heroes(self, text, as_tale=None) -> str:
    """Generates prompt to get heroes description."""
    tales = self.tales
    if as_tale:
      tales = [tale for tale in self.tales if tale['name'] == as_tale]
    output = []
    for counter, tale in enumerate(tales, 1):
      output.append(self.HEROES.format(
          counter=counter, text=tale['summary'], heroes=tale['heroes']))
    predict = self.HEROES_PREDICT.format(counter=len(tales) + 1, text=text)
    output.append(predict)
    return '\n'.join(output)

  def get_heroes(self, as_tale=None, max_tokens=500):
    prompt = self.prompt_heroes(self.line, as_tale)
    print('PROMPT:\n%s' % prompt)
    result = generate(
        prompt, num_generations=3, temperature=0.618, max_tokens=max_tokens)
    for idx, gen in enumerate(result['generation'].values):
      descriptions = re.findall('\<description\>\s(.*?)\s<stop>', gen, re.DOTALL)
      names = re.findall('\<character\>\s(.*?)\s<description>', gen, re.DOTALL)
      self.heroes[idx] = {'names': names, 'descriptions': descriptions}
    return self.heroes

  def get_structure(self, heroes=None, max_tokens=500):
    text = [self.line]
    if heroes is not None:
      text.append('\n'.join(self.heroes[heroes]['descriptions']))
    prompt = self.prompt_structure('\n'.join(text))
    print('PROMPT:\n%s' % prompt)
    output = generate(
        prompt, num_generations=3, temperature=0.88, max_tokens=max_tokens)
    for idx, gen in enumerate(output['generation'].values):
      matched = re.search('(1\).*?)\n\n', gen, re.DOTALL)
      if matched:
        self.structures[idx] = matched.group()
    return self.structures

  def get_tale(self, as_tale, structure=None, heroes=None, max_tokens=500):
    text = [self.line]
    if heroes is not None:
       text.append('\n'.join(self.heroes[heroes]['descriptions']))
    if structure is not None:
      text.append(self.structures[structure])
    prompt = self.prompt_text_as_tale('\n'.join(text), as_tale)
    print('PROMPT:\n%s' % prompt)
    if not prompt:
      return ''
    output = generate(
        prompt, num_generations=3, temperature=0.88, max_tokens=max_tokens)
    for idx, gen in enumerate(output['generation'].values):
      print(f'============')
      print(f'Generation {idx}')
      print(gen)
    return output

# %%
line = '''Fanny fairy tale about two girls: Sasha-nyasha and Stase-kvasya, 
who discovered that an Evil Witch with a magic Candle wants to kidnap the girls 
to make them witches. They learn magic, but they do good deeds all the time and 
because of this they get into funny situations.'''

line1 = '''A fairy tale about two girls: Sasha-nyasha and Stasya-kvasya. About how the lights in their 
apartment suddenly went out and they were looking for how to make it brighter. 
They found candles in the kitchen, lit them, and then a fire broke out and the 
girls put them out.'''

punk_line = """Scifi cyberpunk story about two hackers who find themselves both 
the targets of a cyber intelligence agent who suspects them of stealing $3.5 
million worth of Bitcoin. The two do not know each other, and neither of them 
recalls stealing the sum."""

tales = [t for t in TALES if t['name'] != 'gose']
t = TalePrompt(line, tales=tales)

# %%
heroes = t.get_heroes('bun')
heroes
# Out:
# PROMPT:
# Example 1.
# A fairy tale about a bun that ran away from grandparents, ran away from all animals, but the fox ate it.
# Characters and descriptions:
# <character> Luke Skywalker <description> Luke Skywalker is the hero. A naive farm boy, he will discover
# special powers under the guidance of mentor Ben Kenobi. <stop>
# <character> Ben Kenobi <description> Ben Kenobi is the mentor figure. A recluse Jedi warrior, he will
# take Luke Skywalker as apprentice. <stop>
# <character> Darth Vader <description> Darth Vader is the antagonist. As a commander of the evil Galactic
# Empire, he controls space station The Death Star. <stop>
# <character> Princess Leia <description> Princess Leia is a feisty and brave leader of the Rebellion. She
# holds the plans of the Death Star. She will become Luke's friend. <stop>
# <character> Han Solo <description> Han Solo is a brash mercenary space pilot of the Millenium Falcon and
# ...

# %%
structures = t.get_structure(heroes=0, max_tokens=500)
len(t.structures)
# Out:
# PROMPT:
# Examples of breakdowns of story into Vladimir Propp's "Morphology of a fairy tale" structutre.
#
# Example 1.
# A fairy tale about a daughter who was cared for by the virgin. The girl deceived her, and the Mother of God punished her for it.
#
# <scenes>
#
# 1) Absence (the Virgin Mary has a long way to go. So, she gives the girls the keys to the thirteen gates of heaven)
# 2) Prohibition (You can do twelve doors, but I forbid you to open the thirteenth door! Do not open it, otherwise you will be unhappy!)
# 3) Violation (Once, when all the angels left, out of curiosity, the girl nevertheless opened the thirteenth door)
# 4) Finding out (On her return, the Ever-Virgin looked into her eyes and asked: “Have you unlocked the thirteenth door too?” “No”)
# 5) Issuance (Virgin Mary demanded the keys back)
# 6) A catch (the Virgin Mary found out about the deception and said: “You disobeyed me and, in addition, you lied, and therefore you are not worthy to stay in heaven anymore!”)
# ...

# %%
for k, v in t.structures.items():
  print('=====================\nGEN:%s' % k)
  print(v)
# Out:
# ...
# GEN:0
# 1) Absence (Sasha-nyasha and Stase-kvasya's mother sends them to the Aunt Shura's house)
# 2) Prohibition (Aunty Shura forbids them to do magic)
# 3) Violation (Sasha-nyasha and Stase-kvasya perform magic in front of Aunty Shura)
# 4) Finding out (Aunty Shura discovers that they are doing magic)
# 5) Extradition (Sasha-nyasha and Stase-kvasya say that they did not perform magic, but she says that she will not believe)
# 6) Trick (The Black Cat takes the girls to the forest, and they see a hut, where the Witch lives)
# 7) Aiding (Witch gives the girls a magic candle, and says that the girls must go home before the candle burns out)
# 8) Wrecking (The Black Cat turns the girls into a princess and a wizard)
# 9) Mediation (The Witch sends the princess and wizard home, the princess says that the wizard must take a ride on the sleigh and they fly home)
# 10) Departure (Sasha-nyasha and Stase-kvasya come home)
# ...

# %%
tale = t.get_tale('red_hood', structure=0, heroes=0, max_tokens=600)
# Out:
# PROMPT:
# Examples of breakdowns of story into Vladimir Propp's "Morphology of a fairy tale" structutre.
#
# Example 1.
# The tale tells of a young girl in a red cap who walks through a dark forest to her grandmother's house. When she arrives, she discovers that the wolf has taken her grandmother's place, trying to trick the girl and eventually eat her.
#
# 1) Absence (Little Red Riding Hood leaves her house for her grandmother)
# 2) Prohibition (Mother punishes Little Red Riding Hood so that she, going to her grandmother, does not leave the path)
# 3) Violation (Little Red Riding Hood leaves the path to collect flowers)
# 4) Finding out (The wolf asks Little Red Riding Hood where she is going and where her grandmother lives)
# 5) Extradition (Little Red Riding Hood tells the wolf where her grandmother lives and why she goes to her)
# ...

# %%
tale = t.get_tale('mary', 2, 2, 650)

# %%
tale = t.get_tale('bun', 2, 2, 700)
